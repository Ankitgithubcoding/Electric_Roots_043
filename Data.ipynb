# %%
import pandas as pd

# %%
# Satisfied level dataset
url1="https://drive.google.com/file/d/1ehMkFolQmCyCRO73LoWM78c4uVzj_VnI/view?usp=drive_link"
url1='https://drive.google.com/uc?id=' + url1.split('/')[-2]
SatisfiedLevel = pd.read_csv(url1)

# %%
SatisfiedLevel
# Out:
#    SatisfactionID  SatisfactionLevel
# 0               1  Very Dissatisfied
# 1               2       Dissatisfied
# 2               3            Neutral
# 3               4         Satisfied
# 4               5     Very Satisfied

# %%
SatisfiedLevel.columns
# Out:
# Index(['SatisfactionID', 'SatisfactionLevel'], dtype='object')

# %%
SatisfiedLevel.dtypes
# Out:
# SatisfactionID        int64
# SatisfactionLevel    object
# dtype: object

# %%
# RatingLevel
url2="https://drive.google.com/file/d/1ciDWRN2lb5n5SGzyQIzFtHZVI1RQ9a09/view?usp=drive_link"
url2='https://drive.google.com/uc?id=' + url2.split('/')[-2]
RatingLevel = pd.read_csv(url2)
RatingLevel
# Out:
#    RatingID           RatingLevel
# 0         1          Unacceptable
# 1         2     Needs Improvement
# 2         3     Meets Expectation
# 3         4  Exceeds Expectation
# 4         5      Above and Beyond

# %%
RatingLevel.columns
# Out:
# Index(['RatingID', 'RatingLevel'], dtype='object')

# %%
RatingLevel.dtypes
# Out:
# RatingID        int64
# RatingLevel    object
# dtype: object

# %%
# PerformanceRating
url3="https://drive.google.com/file/d/1bkquRLdL2PIh_BgvQhid_RJSYiDJCvu3/view?usp=sharing"
url3='https://drive.google.com/uc?id=' + url3.split('/')[-2]
PerformanceRating = pd.read_csv(url3)
PerformanceRating
# Out:
#      PerformanceID EmployeeID ReviewDate  EnvironmentSatisfaction  \
# 0             PR01  79F7-78EC   1/2/2013                        5
# 1             PR02  B61E-0F26   1/3/2013                        5
# 2             PR03  F5E3-48BB   1/3/2013                        3
# 3             PR04  0678-748A   1/4/2013                        5
# 4             PR05  541F-3E19   1/4/2013                        5
# ...            ...        ...        ...                      ...
# 6704         PR995  4F28-CFAF  3/14/2016                        5
# 6705         PR996  7C80-94E0  3/14/2016                        3
# 6706         PR997  8233-2483  3/14/2016                        3
# 6707         PR998  8A5B-3D6E  3/15/2016                        5
# 6708         PR999  4500-37EB  3/16/2016                        4
#
#       JobSatisfaction  RelationshipSatisfaction  \
# 0                   4                         5
# 1                   4                         4
# ...

# %%
PerformanceRating.columns
# Out:
# Index(['PerformanceID', 'EmployeeID', 'ReviewDate', 'EnvironmentSatisfaction',
#        'JobSatisfaction', 'RelationshipSatisfaction',
#        'TrainingOpportunitiesWithinYear', 'TrainingOpportunitiesTaken',
#        'WorkLifeBalance', 'SelfRating', 'ManagerRating'],
#       dtype='object')

# %%
PerformanceRating.dtypes
# Out:
# PerformanceID                      object
# EmployeeID                         object
# ReviewDate                         object
# EnvironmentSatisfaction             int64
# JobSatisfaction                     int64
# RelationshipSatisfaction            int64
# TrainingOpportunitiesWithinYear     int64
# TrainingOpportunitiesTaken          int64
# WorkLifeBalance                     int64
# SelfRating                          int64
# ManagerRating                       int64
# dtype: object

# %% [markdown]
# ### Converticing dates in coreect format

# %%
PerformanceRating['ReviewDate']=pd.to_datetime(PerformanceRating['ReviewDate'],errors='coerce')
#PerformanceRating['ReviewDate']=PerformanceRating['ReviewDate'].dt.strftime('%Y-%m-%d')

# %%
PerformanceRating['ReviewDate'].dtype
# Out:
# dtype('<M8[ns]')

# %%
PerformanceRating['ReviewDate'].isna().sum()
# Out:
# 0

# %%
PerformanceRating.isnull().sum()
# Out:
# PerformanceID                      0
# EmployeeID                         0
# ReviewDate                         0
# EnvironmentSatisfaction            0
# JobSatisfaction                    0
# RelationshipSatisfaction           0
# TrainingOpportunitiesWithinYear    0
# TrainingOpportunitiesTaken         0
# WorkLifeBalance                    0
# SelfRating                         0
# ManagerRating                      0
# dtype: int64

# %%
PerformanceRating.dtypes
# Out:
# PerformanceID                              object
# EmployeeID                                 object
# ReviewDate                         datetime64[ns]
# EnvironmentSatisfaction                     int64
# JobSatisfaction                             int64
# RelationshipSatisfaction                    int64
# TrainingOpportunitiesWithinYear             int64
# TrainingOpportunitiesTaken                  int64
# WorkLifeBalance                             int64
# SelfRating                                  int64
# ManagerRating                               int64
# dtype: object

# %%
PerformanceRating['ManagerRating'].unique()
# Out:
# array([4, 3, 2, 5], dtype=int64)

# %%
PerformanceRating.to_csv('PerformanceRating.csv', index=False)

# %%
# Employee
url4="https://drive.google.com/file/d/15uovm3We10afXJ95ioI20rq8nyWKTWyJ/view?usp=drive_link"
url4='https://drive.google.com/uc?id=' + url4.split('/')[-2]
Employee = pd.read_csv(url4)
Employee
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
Employee.columns
# Out:
# Index(['EmployeeID', 'FirstName', 'LastName', 'Gender', 'Age',
#        'BusinessTravel', 'Department', 'DistanceFromHome (KM)', 'State',
#        'Ethnicity', 'Education', 'EducationField', 'JobRole', 'MaritalStatus',
#        'Salary', 'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
Employee.dtypes
# Out:
# EmployeeID                 object
# FirstName                  object
# LastName                   object
# Gender                     object
# Age                         int64
# BusinessTravel             object
# Department                 object
# DistanceFromHome (KM)       int64
# State                      object
# Ethnicity                  object
# Education                   int64
# EducationField             object
# JobRole                    object
# MaritalStatus              object
# Salary                      int64
# StockOptionLevel            int64
# OverTime                   object
# HireDate                   object
# Attrition                  object
# YearsAtCompany              int64
# YearsInMostRecentRole       int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# dtype: object

# %% [markdown]
# ## Converting Hire Date to proper format

# %%
Employee['HireDate']=pd.to_datetime(Employee['HireDate'],errors='coerce')

# %%
Employee['HireDate'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
Employee['HireDate'].isna().sum()
# Out:
# 0

# %%
Employee.dtypes
# Out:
# EmployeeID                         object
# FirstName                          object
# LastName                           object
# Gender                             object
# Age                                 int64
# BusinessTravel                     object
# Department                         object
# DistanceFromHome (KM)               int64
# State                              object
# Ethnicity                          object
# Education                           int64
# EducationField                     object
# JobRole                            object
# MaritalStatus                      object
# Salary                              int64
# StockOptionLevel                    int64
# OverTime                           object
# HireDate                   datetime64[ns]
# Attrition                          object
# YearsAtCompany                      int64
# YearsInMostRecentRole               int64
# YearsSinceLastPromotion             int64
# ...

# %%
# EducationLevel
url5="https://drive.google.com/file/d/1_VGnEhrM_KFwmFjBaVjwKeAe96P66Zro/view?usp=drive_link"
url5='https://drive.google.com/uc?id=' + url5.split('/')[-2]
EducationLevel = pd.read_csv(url5)
EducationLevel
# Out:
#    EducationLevelID            EducationLevel
# 0                 1  No Formal Qualifications
# 1                 2              High School
# 2                 3                Bachelors
# 3                 4                  Masters
# 4                 5                 Doctorate

# %%
EducationLevel.columns
# Out:
# Index(['EducationLevelID', 'EducationLevel'], dtype='object')

# %%
EducationLevel.dtypes
# Out:
# EducationLevelID     int64
# EducationLevel      object
# dtype: object

# %%
Employee.isnull().sum()
# Out:
# EmployeeID                 0
# FirstName                  0
# LastName                   0
# Gender                     0
# Age                        0
# BusinessTravel             0
# Department                 0
# DistanceFromHome (KM)      0
# State                      0
# Ethnicity                  0
# Education                  0
# EducationField             0
# JobRole                    0
# MaritalStatus              0
# Salary                     0
# StockOptionLevel           0
# OverTime                   0
# HireDate                   0
# Attrition                  0
# YearsAtCompany             0
# YearsInMostRecentRole      0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
Employee['DistanceFromHome (KM)'].unique()
# Out:
# array([27, 23, 29, 12, 30, 45,  3, 20,  4, 42,  8, 35, 21, 34, 19,  1, 17,
#        36, 37, 41, 25, 44, 22, 40, 14, 15,  7,  5, 31,  9, 13, 38, 16, 39,
#        28, 32,  2,  6, 11, 33, 26, 43, 10, 18, 24], dtype=int64)

# %%
Employee['OverTime'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
Employee.to_csv('Employee.csv', index=False)

# %%
# u="https://drive.google.com/file/d/1bkquRLdL2PIh_BgvQhid_RJSYiDJCvu3/view?usp=sharing"
# u='https://drive.google.com/uc?id=' + u.split('/')[-2]
# PerformanceRating1 = pd.read_csv(u)
# PerformanceRating1
# Out:
#      PerformanceID EmployeeID ReviewDate  EnvironmentSatisfaction  \
# 0             PR01  79F7-78EC   1/2/2013                        5
# 1             PR02  B61E-0F26   1/3/2013                        5
# 2             PR03  F5E3-48BB   1/3/2013                        3
# 3             PR04  0678-748A   1/4/2013                        5
# 4             PR05  541F-3E19   1/4/2013                        5
# ...            ...        ...        ...                      ...
# 6704         PR995  4F28-CFAF  3/14/2016                        5
# 6705         PR996  7C80-94E0  3/14/2016                        3
# 6706         PR997  8233-2483  3/14/2016                        3
# 6707         PR998  8A5B-3D6E  3/15/2016                        5
# 6708         PR999  4500-37EB  3/16/2016                        4
#
#       JobSatisfaction  RelationshipSatisfaction  \
# 0                   4                         5
# 1                   4                         4
# ...

# %%
PerformanceRating1.head(50)
# Out:
#    PerformanceID EmployeeID ReviewDate  EnvironmentSatisfaction  \
# 0           PR01  79F7-78EC   1/2/2013                        5
# 1           PR02  B61E-0F26   1/3/2013                        5
# 2           PR03  F5E3-48BB   1/3/2013                        3
# 3           PR04  0678-748A   1/4/2013                        5
# 4           PR05  541F-3E19   1/4/2013                        5
# 5           PR06  F93E-BDEF   1/4/2013                        3
# 6           PR07  9E7A-1F70   1/8/2013                        3
# 7           PR08  05ED-92F1  1/10/2013                        4
# 8           PR09  F72D-261D  1/10/2013                        4
# 9           PR10  774E-685D  1/11/2013                        5
# 10         PR100  B013-7D0C  4/10/2013                        4
# 11        PR1000  528C-3E0D  3/16/2016                        4
# 12        PR1001  D077-169C  3/17/2016                        3
# 13        PR1002  9727-BC84  3/18/2016                        4
# ...

# %%
pip install mysqlclient
# Out:
# ...
#    ---------------------------------------- 0.0/207.5 kB ? eta -:--:--
#    - -------------------------------------- 10.2/207.5 kB ? eta -:--:--
#    ------- ------------------------------- 41.0/207.5 kB 653.6 kB/s eta 0:00:01
#    ---------------------------------------  204.8/207.5 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 207.5/207.5 kB 1.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.1 MB 9.4 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/16.1 MB 10.0 MB/s eta 0:00:02
#    --- ------------------------------------ 1.5/16.1 MB 10.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.7/16.1 MB 9.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.1/16.1 MB 9.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.3/16.1 MB 8.8 MB/s eta 0:00:02
#    ------ --------------------------------- 2.8/16.1 MB 8.4 MB/s eta 0:00:02
#    ------- -------------------------------- 3.0/16.1 MB 8.4 MB/s eta 0:00:02
#    -------- ------------------------------- 3.3/16.1 MB 7.9 MB/s eta 0:00:02
#    --------- ------------------------------ 3.6/16.1 MB 7.7 MB/s eta 0:00:02
#    --------- ------------------------------ 3.9/16.1 MB 7.6 MB/s eta 0:00:02
# ...

# %%
pip install pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.0 kB ? eta -:--:--
#    ------------------------------------ --- 41.0/45.0 kB 653.6 kB/s eta 0:00:01
#    ---------------------------------------- 45.0/45.0 kB 439.6 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')
from sqlalchemy import create_engine
import pandas as pd
DATABASE_TYPE = 'mysql' 
DBAPI = 'mysqldb' 
USER = 'root' 
PASSWORD = "Varad%40123" 
HOST = '127.0.0.1' 
PORT = '3306' 
DATABASE = 'electric_roots_043' # Create the engine string 
engine_string = f"{DATABASE_TYPE}+{DBAPI}://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"
engine=create_engine(engine_string)
conn=engine.connect()
PerformanceRating.to_sql('PerformanceRating',engine,index=False,if_exists='replace')

# %%
Employee.to_sql('Employee',engine,index=False,if_exists='replace')
RatingLevel.to_sql('RatingLevel',engine,index=False,if_exists='replace')
SatisfiedLevel.to_sql('SatisfiedLevel',engine,index=False,if_exists='replace')
EducationLevel.to_sql('EducationLevel',engine,index=False,if_exists='replace')
# Out:
# 5
